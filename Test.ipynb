# %%
import os 
from src.crypto import Cryptor, Encryptor, Decryptor

# %%
path = 'examples/dec_example_hero1.jpg'
outpath = 'results/example_output.enc'

# %%
os.makedirs('results', exist_ok = True)

# %%
crp = Cryptor(path, outname = 'results\example_output.enc', create = True)

# %%
encr = Encryptor(path, outname = 'results/example_output.enc', create = True)

# %%
encro = encr._encrypt()

# %%
encr._write_data()

# %%
#### 
path =

# %%
decr = Decryptor(path = outpath, outname = path, create = True)

# %%
decr._decrypt()
# Out:
# b'\xff\x03|R\xae\xd2\xc5\x17\xa3\x14Y\\d\xb8N\xc6\x97\x04EW\xea\xb6\xd6\x98\x1a\x04\xf1\x04\x9a\xfd\x0eB\xb6\x8d\x90\r\xef9\xc9}<<\xca\xf7\xbf\xd0\xd8j+"\xa4{ND\xd4qT\x9a\x11\\)\x11e9\xfb\xfb\xaf\xbf\x80V\x9b\x1f9\xad\xa07\xe1PFpu\xd7\xccd\xfa\xd5\xd5\x87\xe9m\xa8\xd9\xcc\x80\xe4!\xc3\xd3)\xa5\xe2\x90\xd1\x06os\x18\xb0hY\xc0\t\xce\x1d\xc6\xc8\x91\'\x11V*\x9b\xa5i\xae\x9c\xb6\xa0\x1f\x1f|\x02\xc1\xe1*\x82\n\xc11,\xecK\x90.\x87\x9af\x9ex\x84W>\x15\xfb\xcd\xfa\x97\xf3\xbe0~\xd2\x19||L^[\xda\xe8\x01\x18\x94\x82t"\xb4\xa2\x05b_\xe0\x82O\xf5lGr1V&K\xb3\x9f\xa0\xe5\xf3\xf9\xedL\xb9\xffX\x1d\x90\xc5>\x1a#o\xff\xbc\xa6\xc6\x8e\x13\xea6\xad\xb3IdP\xbd?\x08\x1e\x80\xd9\xf9\x17\x9f\x86|\xf2q\xc1\x88\xcf``\xb76\xa1\xc2\xc1\x18\xdf<@ \xd1\x1a\xb4\x06\xda\x9a\xc9\x10 ,\x1cm\xe1\xe9%g^\x95\x0e\xda\xf0\xe5\xef\xa2J\xeb\xef\x87\x8e\xcaio2\x93\x99\xd4,e\xbb5R\x89\xbc\xf5\xf2w\x04\xe1W\x19&\xb7\xfbk\xb4\x00\xdc\xd0\x8a\xedA\xb2\x9a\x16\x08\xdbV\x0ez\xc6\xf8\x1b\xf7\x9e\xaa\x85w\xa3\xb5\x9e\xbf\x07\xfd\x
# ...

# %%
decr._write_data()
